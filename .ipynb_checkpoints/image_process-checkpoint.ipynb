# %%
import math
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %%
image = './memage2.jpg'
kernel = np.ones((3,3),np.uint8)
image = cv2.imread(image, 0)
image2 = image.copy()

# THIS DIFFERENT FILTER TO HAND (DETECT BY COLOR)
# BUT NOW I WORK ONLY WITH WB IMAGE
#
# image = cv2.GaussianBlur(image,(5,5),cv2.BORDER_DEFAULT)
# image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
# blurred = cv2.GaussianBlur(image, (3, 3), 0)
#
# lower_skin = np.array([0,0,100], dtype=np.uint8)
# upper_skin = np.array([20,255,255], dtype=np.uint8)
# mask = cv2.inRange(image, lower_skin, upper_skin)

retval, mask = cv2.threshold(image, 120, 255, cv2.THRESH_BINARY)
mask = cv2.dilate(mask, kernel, iterations=4)
mask = cv2.GaussianBlur(mask, (5,5), 100)


contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

max_contour = max(contours,key=lambda x: cv2.contourArea(x))
cnt = contours[0] # delete excess dim for list
max_hull = cv2.convexHull(max_contour)
epsilon = 0.001*cv2.arcLength(max_contour,True)
approx= cv2.approxPolyDP(max_contour,epsilon,True)

hull = cv2.convexHull(cnt, returnPoints=False)
defects = cv2.convexityDefects(cnt, hull)

final = cv2.drawContours(image, [approx], -1, (0, 0, 0), 2)

for i in range(defects.shape[0]):
    s,e,f,d = defects[i,0]
    start = tuple(cnt[s][0])
    end = tuple(cnt[e][0])
    far = tuple(cnt[f][0])
    cv2.line(image2,start,end,[0,255,0],2)
    cv2.circle(image2,far,5,[0,0,255],-1)
plt.figure(figsize=(10, 10))
plt.imshow(final) #cmap='gray', interpolation='nearest')
plt.figure(figsize=(10,10))
plt.imshow(image2)

plt.show()

# %%
height, width = image.shape
blank_image = np.zeros((height,width,3), np.uint8)+255
contours_angle = cv2.drawContours(blank_image, [approx],-1,(0,0,0),2)
contours_angles = cv2.cvtColor(contours_angle, cv2.COLOR_RGB2GRAY)
corners = cv2.goodFeaturesToTrack(contours_angles, 100, 0.3, 10)
corners = np.int0(corners)

for corner in corners:
    x,y = corner.ravel()
    cv2.circle(contours_angles,(x,y),5,(0,255,0),-1)

plt.figure(figsize=(10,10))    
plt.imshow(contours_angles)
#print(contours)

# %%
image = cv2.imread('./memage2.jpg')
blank_image = np.zeros((height,width,3), np.uint8)+255
for i in corners:
    i = i.ravel()
    for j in corners:
        j = j.ravel()
        if sum(i == j) >= 2:
            continue
        distance = np.linalg.norm(i-j)
        angle = (i*j)/(np.linalg.norm(i)*np.linalg.norm(j)_
        # print(f'distance between: {i} and {j} equal - {distance}')
        if distance > 120 and distance<220 and angle(i,j): 
            cv2.line(image, tuple(i.ravel()), tuple(j.ravel()),(0,255,0),1)
plt.figure(figsize=(10,10))
plt.imshow(image)

# %%
angle = lambda i,j: math.acos(sum(i*j)/(np.linalg.norm(i)*np.linalg.norm(j)))*180/math.pi
angle(np.array([6,3]),np.array([5,13]))
# Out:
# 42.3974377975002
