# %%
import math
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %%
image = './memage2.jpg'
kernel = np.ones((3,3),np.uint8)
image = cv2.imread(image)
image2 = image.copy()

image = cv2.GaussianBlur(image,(5,5),cv2.BORDER_DEFAULT)
image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# hsv ranges for hand skin
lower_skin = np.array([0,0,110], dtype=np.uint8)
upper_skin = np.array([255,80,255], dtype=np.uint8)
mask = cv2.inRange(image, lower_skin, upper_skin)


contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

max_contour = max(contours,key=lambda x: cv2.contourArea(x))
cnt = contours[0] # delete excess dim for list
max_hull = cv2.convexHull(max_contour)
epsilon = 0.003*cv2.arcLength(max_contour,True)
approx= cv2.approxPolyDP(max_contour,epsilon,True)

hull = cv2.convexHull(cnt, returnPoints=False)
defects = cv2.convexityDefects(cnt, hull)

final = cv2.drawContours(image, [max_hull], -1, (255, 0, 0), 5)
final = cv2.drawContours(image, approx, -1, (0,255,0),5)
"""
l=0
for i in range(defects.shape[0]):
    s,e,f,d = defects[i,0]
    start = approx[s][0]
    end = approx[e][0]
    far = approx[f][0]
    a = np.linalg.norm(start-end)
    b = np.linalg.norm(start-far)
    c = np.linalg.norm(far-end)
    s = (a + b + c) / 2
    ar = math.sqrt(s * (s - a) * (s - b) * (s - c))
            
    #distance between point and convex hull
    d = (2 * ar) / a
            
    # apply cosine rule here
    angle = math.acos((b**2 + c**2 - a**2)/(2*b*c)) * 180 / math.pi
    cv2.circle(image, tuple(far), 5, [255,0,0], -1)       
    cv2.line(image,tuple(start), tuple(end), [0,255,0], 2)
    """
plt.figure(figsize=(10, 10))
plt.imshow(final) #cmap='gray', interpolation='nearest')
plt.figure(figsize=(10,10))
plt.imshow(mask)

plt.show()
# Out:
# 0

# %%
# %%time
image3 = image2.copy()
for num, i in enumerate(approx):
    count = 0 
    for j in max_hull:
        if num == 0:
            x,y = j.ravel()
            cv2.circle(image3, (x, y), 5, (255,0,0),-1)
        if np.linalg.norm(j-i) < 90 and np.linalg.norm(j-i)>0:
            count+=1   
    if count < 1:
        x, y = i.ravel()
        cv2.circle(image3, (x,y), 5 ,(0,255,0),-1)
    
plt.imshow(image3)
# Out:
# CPU times: user 120 ms, sys: 4.1 ms, total: 124 ms
# Wall time: 168 ms

# %%
image = cv2.imread('./memage2.jpg')
blank_image = np.zeros((height,width,3), np.uint8)+255
for i in corners:
    i = i.ravel()
    for j in corners:
        j = j.ravel()
        if sum(i == j) >= 2:
            continue
        distance = np.linalg.norm(i-j)
        angle = (i*j)/(np.linalg.norm(i)*np.linalg.norm(j))
        # print(f'distance between: {i} and {j} equal - {distance}')
        if distance > 120 and distance<220: 
            cv2.line(image, tuple(i.ravel()), tuple(j.ravel()),(0,255,0),1)
plt.figure(figsize=(10,10))
plt.imshow(image)

# %%
angle = lambda i,j: math.acos(sum(i*j) / (np.linalg.norm(i) * np.linalg.norm(j))) * 180 / math.pi
angle(np.array([6,3]),np.array([5,13]))
# Out:
# 42.3974377975002
